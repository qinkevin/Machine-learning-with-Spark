# %%
path='lfw/*'

# %%
rdd=sc.wholeTextFiles(path)

# %%
rdd.first()
# Out:
# (u'file:/Users/qinkevin/spark/Machine-learning-with-Spark/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg',
# ...

# %%
files=rdd.map(lambda (filename,content):filename.replace('file:',''))

# %%
files.first()
# Out:
# u'/Users/qinkevin/spark/Machine-learning-with-Spark/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg'

# %%
files.count()
# Out:
# 1054

# %%
# %matplotlib inline
